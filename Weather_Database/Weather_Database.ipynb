# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.00, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# coordinates

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descrip})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hamilton
# Processing Record 2 of Set 1 | todos santos
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | albino
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | ballina
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | taltal
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | honiara
# Processing Record 14 of Set 1 | neryungri
# Processing Record 15 of Set 1 | waddan
# Processing Record 16 of Set 1 | san carlos de bariloche
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | faya
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | tsuyama
# Processing Record 23 of Set 1 | marienburg
# Processing Record 24 of Set 1 | lubao
# Processing Record 25 of Set 1 | yachimata
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | requena
# Processing Record 29 of Set 1 | labytnangi
# Processing Record 30 of Set 1 | poddorye
# Processing Record 31 of Set 1 | sorland
# Processing Record 32 of Set 1 | lata
# Processing Record 33 of Set 1 | gizo
# Processing Record 34 of Set 1 | necochea
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | khorinsk
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | burica
# City not found. Skipping...
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | letlhakane
# Processing Record 43 of Set 1 | caravelas
# Processing Record 44 of Set 1 | fortuna
# Processing Record 45 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 2 | ugoofaaru
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | krasnyy bogatyr
# Processing Record 5 of Set 2 | hami
# Processing Record 6 of Set 2 | taoudenni
# Processing Record 7 of Set 2 | prata
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | bilma
# Processing Record 11 of Set 2 | gazni
# City not found. Skipping...
# Processing Record 12 of Set 2 | sao joao da barra
# Processing Record 13 of Set 2 | kruisfontein
# Processing Record 14 of Set 2 | sitka
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | henties bay
# Processing Record 17 of Set 2 | mangrol
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | zyryanka
# Processing Record 20 of Set 2 | maldonado
# Processing Record 21 of Set 2 | kulhudhuffushi
# Processing Record 22 of Set 2 | port lincoln
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | tutoia
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | mandiana
# Processing Record 28 of Set 2 | zhigansk
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | dourbali
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | jackson
# Processing Record 39 of Set 2 | mastic beach
# Processing Record 40 of Set 2 | nara
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | takob
# City not found. Skipping...
# Processing Record 44 of Set 2 | amapa
# Processing Record 45 of Set 2 | karratha
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | moree
# Processing Record 49 of Set 2 | lincolnton
# Processing Record 50 of Set 2 | makakilo city
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | hofn
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | westerland
# Processing Record 10 of Set 3 | alta floresta
# Processing Record 11 of Set 3 | san felipe
# Processing Record 12 of Set 3 | goundam
# Processing Record 13 of Set 3 | mata
# Processing Record 14 of Set 3 | mehamn
# Processing Record 15 of Set 3 | arroyo
# Processing Record 16 of Set 3 | sisimiut
# Processing Record 17 of Set 3 | dukat
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | flinders
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | hayrabolu
# Processing Record 24 of Set 3 | havoysund
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | riyadh
# Processing Record 28 of Set 3 | kirkland lake
# Processing Record 29 of Set 3 | okha
# Processing Record 30 of Set 3 | voh
# Processing Record 31 of Set 3 | diamantino
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | shanghai
# Processing Record 34 of Set 3 | kosikha
# Processing Record 35 of Set 3 | susangerd
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | kangaatsiaq
# Processing Record 39 of Set 3 | sumbe
# Processing Record 40 of Set 3 | yulara
# Processing Record 41 of Set 3 | key west
# Processing Record 42 of Set 3 | prince rupert
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | liberal
# Processing Record 45 of Set 3 | maniwaki
# Processing Record 46 of Set 3 | tambura
# Processing Record 47 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | tazmalt
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | vardo
# Processing Record 2 of Set 4 | santa maria
# Processing Record 3 of Set 4 | hay river
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | saint-augustin
# Processing Record 8 of Set 4 | shaki
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | shimoda
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | qaanaaq
# Processing Record 13 of Set 4 | esso
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | lavumisa
# Processing Record 16 of Set 4 | axim
# Processing Record 17 of Set 4 | iberia
# Processing Record 18 of Set 4 | aksu
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | yangjiang
# Processing Record 21 of Set 4 | pangai
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | buala
# Processing Record 24 of Set 4 | coihueco
# Processing Record 25 of Set 4 | mocuba
# Processing Record 26 of Set 4 | tura
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | saint-pierre
# Processing Record 30 of Set 4 | guerrero negro
# Processing Record 31 of Set 4 | limoeiro
# Processing Record 32 of Set 4 | boyolangu
# Processing Record 33 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 4 | sur
# Processing Record 35 of Set 4 | opuwo
# Processing Record 36 of Set 4 | pisco
# Processing Record 37 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 4 | batagay-alyta
# Processing Record 39 of Set 4 | atyuryevo
# City not found. Skipping...
# Processing Record 40 of Set 4 | sumenep
# Processing Record 41 of Set 4 | puerto escondido
# Processing Record 42 of Set 4 | ilam
# Processing Record 43 of Set 4 | ivanovka
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | narsaq
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | sibolga
# Processing Record 49 of Set 4 | palmer
# Processing Record 50 of Set 4 | san diego de los banos
# Processing Record 1 of Set 5 | bloomington
# Processing Record 2 of Set 5 | praia da vitoria
# Processing Record 3 of Set 5 | bouza
# Processing Record 4 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 5 | ha tinh
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | ahipara
# Processing Record 8 of Set 5 | mar del plata
# Processing Record 9 of Set 5 | yar-sale
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | bobo dioulasso
# Processing Record 13 of Set 5 | novoselytsya
# Processing Record 14 of Set 5 | beringovskiy
# Processing Record 15 of Set 5 | hargeysa
# Processing Record 16 of Set 5 | payo
# Processing Record 17 of Set 5 | cochrane
# Processing Record 18 of Set 5 | rio grande
# Processing Record 19 of Set 5 | leuna
# Processing Record 20 of Set 5 | komatipoort
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | vostok
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | nishihara
# Processing Record 26 of Set 5 | redmond
# Processing Record 27 of Set 5 | sao joao batista
# Processing Record 28 of Set 5 | richards bay
# Processing Record 29 of Set 5 | lasa
# Processing Record 30 of Set 5 | meadow lake
# Processing Record 31 of Set 5 | tukrah
# Processing Record 32 of Set 5 | hambantota
# Processing Record 33 of Set 5 | esil
# Processing Record 34 of Set 5 | los chiles
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | billings
# Processing Record 37 of Set 5 | solnechnyy
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | san patricio
# Processing Record 40 of Set 5 | pelotas
# Processing Record 41 of Set 5 | inhambane
# Processing Record 42 of Set 5 | vila
# Processing Record 43 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 44 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 5 | kashi
# Processing Record 46 of Set 5 | korla
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | angoche
# Processing Record 49 of Set 5 | nikolskoye
# Processing Record 50 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | chaves
# Processing Record 3 of Set 6 | mikhaylov
# Processing Record 4 of Set 6 | linxia
# Processing Record 5 of Set 6 | maceio
# Processing Record 6 of Set 6 | los llanos de aridane
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | hadejia
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | nantucket
# Processing Record 11 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 6 | micheweni
# Processing Record 14 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | bethel
# Processing Record 17 of Set 6 | kununurra
# Processing Record 18 of Set 6 | sychevka
# Processing Record 19 of Set 6 | namatanai
# Processing Record 20 of Set 6 | reconquista
# Processing Record 21 of Set 6 | constantine
# Processing Record 22 of Set 6 | kamra
# Processing Record 23 of Set 6 | belyy
# Processing Record 24 of Set 6 | rawson
# Processing Record 25 of Set 6 | candido de abreu
# Processing Record 26 of Set 6 | ewa beach
# Processing Record 27 of Set 6 | meulaboh
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | komsomolskiy
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | tynda
# Processing Record 33 of Set 6 | khorramshahr
# Processing Record 34 of Set 6 | klaksvik
# Processing Record 35 of Set 6 | khonsar
# City not found. Skipping...
# Processing Record 36 of Set 6 | tete
# Processing Record 37 of Set 6 | saint anthony
# Processing Record 38 of Set 6 | talaya
# Processing Record 39 of Set 6 | nassau
# Processing Record 40 of Set 6 | paita
# Processing Record 41 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 6 | andenes
# Processing Record 43 of Set 6 | broken hill
# Processing Record 44 of Set 6 | waipawa
# Processing Record 45 of Set 6 | botou
# Processing Record 46 of Set 6 | san cristobal
# Processing Record 47 of Set 6 | iquitos
# Processing Record 48 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 6 | hithadhoo
# Processing Record 50 of Set 6 | vao
# Processing Record 1 of Set 7 | puerto quijarro
# Processing Record 2 of Set 7 | naryan-mar
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | tessalit
# Processing Record 5 of Set 7 | camacha
# Processing Record 6 of Set 7 | kuvandyk
# Processing Record 7 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 7 | muhammadabad
# Processing Record 9 of Set 7 | longyearbyen
# Processing Record 10 of Set 7 | alice town
# Processing Record 11 of Set 7 | natal
# Processing Record 12 of Set 7 | isangel
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | marzuq
# Processing Record 15 of Set 7 | kagadi
# Processing Record 16 of Set 7 | grand-santi
# Processing Record 17 of Set 7 | petropavlovka
# Processing Record 18 of Set 7 | biltine
# Processing Record 19 of Set 7 | abha
# Processing Record 20 of Set 7 | manicore
# Processing Record 21 of Set 7 | santa cruz
# Processing Record 22 of Set 7 | dikson
# Processing Record 23 of Set 7 | rocha
# Processing Record 24 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 7 | batagay
# Processing Record 26 of Set 7 | zhezkazgan
# Processing Record 27 of Set 7 | sept-iles
# Processing Record 28 of Set 7 | laguna
# Processing Record 29 of Set 7 | la rioja
# Processing Record 30 of Set 7 | sooke
# Processing Record 31 of Set 7 | cherskiy
# Processing Record 32 of Set 7 | guaruja
# Processing Record 33 of Set 7 | santa rosa
# Processing Record 34 of Set 7 | nome
# Processing Record 35 of Set 7 | crawfordsville
# Processing Record 36 of Set 7 | gombong
# Processing Record 37 of Set 7 | aklavik
# Processing Record 38 of Set 7 | awjilah
# Processing Record 39 of Set 7 | fort nelson
# Processing Record 40 of Set 7 | olafsvik
# Processing Record 41 of Set 7 | yerbogachen
# Processing Record 42 of Set 7 | paamiut
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | hanmer springs
# Processing Record 45 of Set 7 | san vicente
# Processing Record 46 of Set 7 | pevek
# Processing Record 47 of Set 7 | varca
# Processing Record 48 of Set 7 | puerto madryn
# Processing Record 49 of Set 7 | olinda
# Processing Record 50 of Set 7 | hailar
# Processing Record 1 of Set 8 | skibbereen
# Processing Record 2 of Set 8 | karsun
# Processing Record 3 of Set 8 | leningradskiy
# Processing Record 4 of Set 8 | bantou
# Processing Record 5 of Set 8 | kurilsk
# Processing Record 6 of Set 8 | winnemucca
# Processing Record 7 of Set 8 | homer
# Processing Record 8 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 8 | lorengau
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | rovinj
# Processing Record 13 of Set 8 | katsuura
# Processing Record 14 of Set 8 | matara
# Processing Record 15 of Set 8 | lamar
# Processing Record 16 of Set 8 | sainte-suzanne
# Processing Record 17 of Set 8 | atherton
# Processing Record 18 of Set 8 | bida
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | vangaindrano
# Processing Record 21 of Set 8 | baghdad
# Processing Record 22 of Set 8 | airai
# Processing Record 23 of Set 8 | kamsack
# Processing Record 24 of Set 8 | dzilam gonzalez
# Processing Record 25 of Set 8 | sibu
# Processing Record 26 of Set 8 | tadine
# Processing Record 27 of Set 8 | zelenoborskiy
# Processing Record 28 of Set 8 | chokurdakh
# Processing Record 29 of Set 8 | seymchan
# Processing Record 30 of Set 8 | aseri
# Processing Record 31 of Set 8 | conde
# Processing Record 32 of Set 8 | san alberto
# Processing Record 33 of Set 8 | barra do garcas
# Processing Record 34 of Set 8 | huangpi
# Processing Record 35 of Set 8 | juli
# Processing Record 36 of Set 8 | dumka
# Processing Record 37 of Set 8 | inyonga
# Processing Record 38 of Set 8 | kloulklubed
# Processing Record 39 of Set 8 | ocampo
# Processing Record 40 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 8 | marsa matruh
# Processing Record 42 of Set 8 | pasighat
# Processing Record 43 of Set 8 | alizai
# Processing Record 44 of Set 8 | pafos
# Processing Record 45 of Set 8 | boali
# Processing Record 46 of Set 8 | maningrida
# Processing Record 47 of Set 8 | bama
# Processing Record 48 of Set 8 | sayyan
# Processing Record 49 of Set 8 | margate
# Processing Record 50 of Set 8 | hervey bay
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | blyth
# Processing Record 3 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 4 of Set 9 | saint-francois
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 9 | najran
# Processing Record 8 of Set 9 | artyom
# Processing Record 9 of Set 9 | male
# Processing Record 10 of Set 9 | linjiang
# Processing Record 11 of Set 9 | beidao
# Processing Record 12 of Set 9 | mbandaka
# Processing Record 13 of Set 9 | rovaniemi
# Processing Record 14 of Set 9 | barguzin
# Processing Record 15 of Set 9 | gat
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | astana
# Processing Record 18 of Set 9 | agartala
# Processing Record 19 of Set 9 | codrington
# Processing Record 20 of Set 9 | mayor pablo lagerenza
# Processing Record 21 of Set 9 | goure
# Processing Record 22 of Set 9 | ippy
# Processing Record 23 of Set 9 | jieshi
# Processing Record 24 of Set 9 | narrabri
# Processing Record 25 of Set 9 | talcahuano
# Processing Record 26 of Set 9 | deputatskiy
# Processing Record 27 of Set 9 | port moresby
# Processing Record 28 of Set 9 | kaniama
# Processing Record 29 of Set 9 | sabha
# Processing Record 30 of Set 9 | chizhou
# Processing Record 31 of Set 9 | luderitz
# Processing Record 32 of Set 9 | whitehorse
# Processing Record 33 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 9 | sao filipe
# Processing Record 35 of Set 9 | comodoro rivadavia
# Processing Record 36 of Set 9 | konstantinovka
# Processing Record 37 of Set 9 | sar-e pul
# Processing Record 38 of Set 9 | constitucion
# Processing Record 39 of Set 9 | sault sainte marie
# Processing Record 40 of Set 9 | port said
# Processing Record 41 of Set 9 | mogadishu
# Processing Record 42 of Set 9 | pingliang
# Processing Record 43 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 9 | port-gentil
# Processing Record 45 of Set 9 | uyemskiy
# Processing Record 46 of Set 9 | katherine
# Processing Record 47 of Set 9 | tubinskiy
# Processing Record 48 of Set 9 | butterworth
# Processing Record 49 of Set 9 | xai-xai
# Processing Record 50 of Set 9 | laramie
# Processing Record 1 of Set 10 | nhulunbuy
# Processing Record 2 of Set 10 | sinnamary
# Processing Record 3 of Set 10 | carutapera
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | central point
# Processing Record 6 of Set 10 | pouso alegre
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | fallon
# Processing Record 9 of Set 10 | el colomo
# Processing Record 10 of Set 10 | phan thiet
# Processing Record 11 of Set 10 | krasnoselkup
# Processing Record 12 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 10 | ribeira brava
# Processing Record 14 of Set 10 | morondava
# Processing Record 15 of Set 10 | vila velha
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | da nang
# Processing Record 18 of Set 10 | nizwa
# Processing Record 19 of Set 10 | quelimane
# Processing Record 20 of Set 10 | la quinta
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | isparta
# Processing Record 23 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 10 | hauterive
# City not found. Skipping...
# Processing Record 25 of Set 10 | nanortalik
# City not found. Skipping...
# Processing Record 26 of Set 10 | saint-georges
# City not found. Skipping...
# Processing Record 27 of Set 10 | pangnirtung
# City not found. Skipping...
# Processing Record 28 of Set 10 | suntar
# City not found. Skipping...
# Processing Record 29 of Set 10 | gimli
# City not found. Skipping...
# Processing Record 30 of Set 10 | le port
# City not found. Skipping...
# Processing Record 31 of Set 10 | farafangana
# City not found. Skipping...
# Processing Record 32 of Set 10 | santa maria do suacui
# City not found. Skipping...
# Processing Record 33 of Set 10 | belaya gora
# City not found. Skipping...
# Processing Record 34 of Set 10 | bundaberg
# City not found. Skipping...
# Processing Record 35 of Set 10 | lavrentiya
# City not found. Skipping...
# Processing Record 36 of Set 10 | santa cruz de tenerife
# City not found. Skipping...
# Processing Record 37 of Set 10 | mezen
# City not found. Skipping...
# Processing Record 38 of Set 10 | kirishi
# City not found. Skipping...
# Processing Record 39 of Set 10 | plerin
# City not found. Skipping...
# Processing Record 40 of Set 10 | okhotsk
# Processing Record 41 of Set 10 | amurrio
# Processing Record 42 of Set 10 | abnub
# Processing Record 43 of Set 10 | kabo
# Processing Record 44 of Set 10 | kermanshah
# Processing Record 45 of Set 10 | tall kayf
# Processing Record 46 of Set 10 | severo-yeniseyskiy
# Processing Record 47 of Set 10 | sovetskiy
# Processing Record 48 of Set 10 | buenos aires
# Processing Record 49 of Set 10 | samarai
# Processing Record 50 of Set 10 | ixtapa
# Processing Record 1 of Set 11 | biloela
# Processing Record 2 of Set 11 | belmonte
# Processing Record 3 of Set 11 | bentiu
# Processing Record 4 of Set 11 | borogontsy
# Processing Record 5 of Set 11 | belyy yar
# Processing Record 6 of Set 11 | mersing
# Processing Record 7 of Set 11 | lumeje
# Processing Record 8 of Set 11 | buxton
# Processing Record 9 of Set 11 | nanakuli
# Processing Record 10 of Set 11 | vavuniya
# Processing Record 11 of Set 11 | kutum
# Processing Record 12 of Set 11 | kemijarvi
# Processing Record 13 of Set 11 | davila
# Processing Record 14 of Set 11 | ambilobe
# Processing Record 15 of Set 11 | bontang
# Processing Record 16 of Set 11 | kaili
# Processing Record 17 of Set 11 | salalah
# Processing Record 18 of Set 11 | mabaruma
# Processing Record 19 of Set 11 | ketchikan
# Processing Record 20 of Set 11 | ville-marie
# Processing Record 21 of Set 11 | ducheng
# Processing Record 22 of Set 11 | hvolsvollur
# Processing Record 23 of Set 11 | rio gallegos
# Processing Record 24 of Set 11 | saulkrasti
# Processing Record 25 of Set 11 | murmashi
# Processing Record 26 of Set 11 | novo aripuana
# Processing Record 27 of Set 11 | tecoanapa
# Processing Record 28 of Set 11 | moron
# Processing Record 29 of Set 11 | ciudad real
# Processing Record 30 of Set 11 | iaciara
# Processing Record 31 of Set 11 | allanridge
# Processing Record 32 of Set 11 | boo
# Processing Record 33 of Set 11 | nechi
# Processing Record 34 of Set 11 | kasongo-lunda
# Processing Record 35 of Set 11 | sola
# Processing Record 36 of Set 11 | mexico
# Processing Record 37 of Set 11 | pastos bons
# Processing Record 38 of Set 11 | ilulissat
# Processing Record 39 of Set 11 | dolores
# Processing Record 40 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 41 of Set 11 | port augusta
# Processing Record 42 of Set 11 | bawku
# Processing Record 43 of Set 11 | rapid valley
# Processing Record 44 of Set 11 | mount isa
# Processing Record 45 of Set 11 | cap malheureux
# Processing Record 46 of Set 11 | saint-joseph
# Processing Record 47 of Set 11 | rovigo
# Processing Record 48 of Set 11 | yumen
# Processing Record 49 of Set 11 | harbour breton
# Processing Record 50 of Set 11 | newberry
# Processing Record 1 of Set 12 | manihari
# Processing Record 2 of Set 12 | yukon
# Processing Record 3 of Set 12 | akdepe
# Processing Record 4 of Set 12 | diego de almagro
# Processing Record 5 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 12 | dallas
# Processing Record 7 of Set 12 | halifax
# Processing Record 8 of Set 12 | rio cuarto
# Processing Record 9 of Set 12 | kandrian
# Processing Record 10 of Set 12 | svoronos
# Processing Record 11 of Set 12 | portland
# Processing Record 12 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 13 of Set 12 | sioux lookout
# Processing Record 14 of Set 12 | el real de santa maria
# Processing Record 15 of Set 12 | ostersund
# Processing Record 16 of Set 12 | half moon bay
# Processing Record 17 of Set 12 | lagos
# Processing Record 18 of Set 12 | martin
# Processing Record 19 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 12 | port hardy
# Processing Record 21 of Set 12 | florianopolis
# Processing Record 22 of Set 12 | pistsovo
# Processing Record 23 of Set 12 | otavi
# Processing Record 24 of Set 12 | shcholkine
# City not found. Skipping...
# Processing Record 25 of Set 12 | manvi
# Processing Record 26 of Set 12 | gusau
# Processing Record 27 of Set 12 | gunnedah
# Processing Record 28 of Set 12 | atambua
# Processing Record 29 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 12 | sidi ali
# Processing Record 31 of Set 12 | rauma
# Processing Record 32 of Set 12 | gao
# Processing Record 33 of Set 12 | general roca
# Processing Record 34 of Set 12 | tulghes
# Processing Record 35 of Set 12 | abu dhabi
# Processing Record 36 of Set 12 | merauke
# Processing Record 37 of Set 12 | sinjar
# Processing Record 38 of Set 12 | chone
# Processing Record 39 of Set 12 | shingu
# Processing Record 40 of Set 12 | vestmannaeyjar
# Processing Record 41 of Set 12 | invermere
# Processing Record 42 of Set 12 | inuvik
# Processing Record 43 of Set 12 | copperas cove
# Processing Record 44 of Set 12 | te anau
# Processing Record 45 of Set 12 | almoloya
# Processing Record 46 of Set 12 | susehri
# Processing Record 47 of Set 12 | bathsheba
# Processing Record 48 of Set 12 | izhma
# Processing Record 49 of Set 12 | staromyshastovskaya
# Processing Record 50 of Set 12 | ust-tsilma
# Processing Record 1 of Set 13 | nang rong
# Processing Record 2 of Set 13 | gambo
# Processing Record 3 of Set 13 | rabaul
# Processing Record 4 of Set 13 | chabahar
# Processing Record 5 of Set 13 | baherden
# Processing Record 6 of Set 13 | kitimat
# Processing Record 7 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 13 | el alto
# Processing Record 9 of Set 13 | beyneu
# Processing Record 10 of Set 13 | adrar
# Processing Record 11 of Set 13 | bilibino
# Processing Record 12 of Set 13 | erzin
# Processing Record 13 of Set 13 | veisiejai
# Processing Record 14 of Set 13 | ashtabula
# Processing Record 15 of Set 13 | tornio
# Processing Record 16 of Set 13 | ust-omchug
# Processing Record 17 of Set 13 | weyburn
# Processing Record 18 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 13 | tsaratanana
# Processing Record 20 of Set 13 | wahpeton
# Processing Record 21 of Set 13 | muzquiz
# City not found. Skipping...
# Processing Record 22 of Set 13 | atasu
# Processing Record 23 of Set 13 | jovellar
# Processing Record 24 of Set 13 | mayskiy
# Processing Record 25 of Set 13 | batemans bay
# Processing Record 26 of Set 13 | mahenge
# Processing Record 27 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 13 | khor
# Processing Record 29 of Set 13 | ayan
# Processing Record 30 of Set 13 | mao
# Processing Record 31 of Set 13 | cairns
# Processing Record 32 of Set 13 | usinsk
# Processing Record 33 of Set 13 | general cepeda
# Processing Record 34 of Set 13 | hoopstad
# Processing Record 35 of Set 13 | elban
# Processing Record 36 of Set 13 | conceicao do araguaia
# Processing Record 37 of Set 13 | noshiro
# Processing Record 38 of Set 13 | pustoshka
# Processing Record 39 of Set 13 | avera
# Processing Record 40 of Set 13 | tiznit
# Processing Record 41 of Set 13 | moose factory
# Processing Record 42 of Set 13 | kuressaare
# Processing Record 43 of Set 13 | shenjiamen
# Processing Record 44 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 13 | moctezuma
# Processing Record 46 of Set 13 | butte
# Processing Record 47 of Set 13 | bambous virieux
# Processing Record 48 of Set 13 | kalmunai
# Processing Record 49 of Set 13 | dali
# Processing Record 50 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 14 | gawler
# Processing Record 2 of Set 14 | eyl
# Processing Record 3 of Set 14 | kinablangan
# Processing Record 4 of Set 14 | autun
# Processing Record 5 of Set 14 | greeneville
# Processing Record 6 of Set 14 | englewood
# Processing Record 7 of Set 14 | yamada
# Processing Record 8 of Set 14 | mbuguni
# Processing Record 9 of Set 14 | la plata
# Processing Record 10 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 14 | kiruna
# Processing Record 12 of Set 14 | socorro
# Processing Record 13 of Set 14 | ossora
# Processing Record 14 of Set 14 | neyshabur
# Processing Record 15 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 14 | tarakan
# Processing Record 17 of Set 14 | houston
# Processing Record 18 of Set 14 | canchungo
# Processing Record 19 of Set 14 | itacoatiara
# Processing Record 20 of Set 14 | lhokseumawe
# Processing Record 21 of Set 14 | dentsville
# Processing Record 22 of Set 14 | nagar karnul
# Processing Record 23 of Set 14 | aracoiaba
# Processing Record 24 of Set 14 | oktyabrskoye
# Processing Record 25 of Set 14 | la ronge
# Processing Record 26 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 27 of Set 14 | high level
# Processing Record 28 of Set 14 | chara
# Processing Record 29 of Set 14 | goderich
# Processing Record 30 of Set 14 | coolum beach
# Processing Record 31 of Set 14 | asau
# Processing Record 32 of Set 14 | san juan
# Processing Record 33 of Set 14 | coos bay
# Processing Record 34 of Set 14 | fuerte olimpo
# Processing Record 35 of Set 14 | palasa
# Processing Record 36 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 14 | manakara
# Processing Record 38 of Set 14 | namibe
# Processing Record 39 of Set 14 | guadalupe y calvo
# Processing Record 40 of Set 14 | peniche
# Processing Record 41 of Set 14 | carmen
# Processing Record 42 of Set 14 | bowen
# Processing Record 43 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 14 | pavilosta
# Processing Record 45 of Set 14 | salinas
# Processing Record 46 of Set 14 | trzcianka
# Processing Record 47 of Set 14 | labuhan
# Processing Record 48 of Set 14 | kansas city
# Processing Record 49 of Set 14 | lazaro cardenas
# Processing Record 50 of Set 14 | denpasar
# Processing Record 1 of Set 15 | atar
# Processing Record 2 of Set 15 | lucapa
# Processing Record 3 of Set 15 | szydlowiec
# Processing Record 4 of Set 15 | grindavik
# Processing Record 5 of Set 15 | aykhal
# Processing Record 6 of Set 15 | belton
# Processing Record 7 of Set 15 | ucluelet
# Processing Record 8 of Set 15 | celestun
# Processing Record 9 of Set 15 | dindori
# Processing Record 10 of Set 15 | calamar
# Processing Record 11 of Set 15 | ushtobe
# Processing Record 12 of Set 15 | tuatapere
# Processing Record 13 of Set 15 | bastrop
# Processing Record 14 of Set 15 | cefalu
# Processing Record 15 of Set 15 | bonavista
# Processing Record 16 of Set 15 | pueblo nuevo
# Processing Record 17 of Set 15 | broome
# Processing Record 18 of Set 15 | luwuk
# Processing Record 19 of Set 15 | burgkirchen
# Processing Record 20 of Set 15 | byron bay
# Processing Record 21 of Set 15 | lake cowichan
# Processing Record 22 of Set 15 | gainesville
# Processing Record 23 of Set 15 | ruidoso
# Processing Record 24 of Set 15 | victor harbor
# Processing Record 25 of Set 15 | port keats
# Processing Record 26 of Set 15 | dire
# Processing Record 27 of Set 15 | panguna
# Processing Record 28 of Set 15 | santo tomas
# Processing Record 29 of Set 15 | milkovo
# Processing Record 30 of Set 15 | murray bridge
# Processing Record 31 of Set 15 | port hedland
# Processing Record 32 of Set 15 | sijunjung
# Processing Record 33 of Set 15 | basco
# Processing Record 34 of Set 15 | muroto
# Processing Record 35 of Set 15 | trelew
# Processing Record 36 of Set 15 | casper
# Processing Record 37 of Set 15 | egvekinot
# Processing Record 38 of Set 15 | grand gaube
# Processing Record 39 of Set 15 | anadyr
# Processing Record 40 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 15 | castelo do piaui
# Processing Record 42 of Set 15 | galle
# Processing Record 43 of Set 15 | watsa
# Processing Record 44 of Set 15 | ozieri
# Processing Record 45 of Set 15 | svetlogorsk
# Processing Record 46 of Set 15 | leh
# Processing Record 47 of Set 15 | aswan
# Processing Record 48 of Set 15 | crixas
# Processing Record 49 of Set 15 | hit
# Processing Record 50 of Set 15 | garachine
# Processing Record 1 of Set 16 | swan river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hamilton      US  39.1834  -84.5333     60.98        79         100
# 1  Todos Santos      MX  23.4500 -110.2167     80.11        74          92
# 2      Bengkulu      ID  -3.8004  102.2655     76.28        88          75
# 3    Butaritari      KI   3.0707  172.7902     81.79        77         100
# 4       Rikitea      PF -23.1203 -134.9692     77.67        68          68
# 5        Albino      IT  45.7638    9.7964     40.32        90          75
# 6       Ballina      AU -28.8667  153.5667     77.04        69         100
# 7     Ostrovnoy      RU  68.0531   39.5131     14.05        87         100
# 8        Taltal      CL -25.4000  -70.4833     67.21        78          45
# 9  Quatre Cocos      MU -20.2078   57.7625     76.08        81          97
#
#    Wind Speed Current Description
# 0        5.01     overcast clouds
# 1        6.44     overcast clouds
# 2        4.56       broken clouds
# 3        9.62     overcast clouds
# 4        8.77       broken clouds
# 5        1.14                mist
# 6        5.99     overcast clouds
# 7       17.87     overcast clouds
# 8        1.43    scattered clouds
# 9        2.10     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
